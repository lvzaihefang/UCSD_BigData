# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
import sys,os
cwd=os.getcwd()
path=cwd.split('/')
home_dir='/'.join(path[:-2])
print home_dir
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
# Out:
# /home/ubuntu/UCSD_BigData

# %%
import pickle
Creds_file='/home/ubuntu/Vault/Creds.pkl'
Creds= pickle.load(open(Creds_file,'rb'))
print Creds.keys()
print Creds['mrjob'].keys()
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print ID,key_id
# Out:
# ['launcher', 'mrjob']
# ['key_id', 'secret_key', 's3_logs', 'ID', 's3_scratch']
# r4he AKIAISHBCJLKEX3YBOWA

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
job_flow_id
# Out:
# <boto.emr.emrobject.JobFlow object at 0x3fc3ed0> no_script.yoavfreund.20140516.040032.370095 j-262J0JTFJIRLO WAITING
# <boto.emr.emrobject.JobFlow object at 0x44c7d10> no_script.yoavfreund.20140517.080731.371759 j-1RE8D7HBISOI0 WAITING
# u'j-1RE8D7HBISOI0'

# %%
data_dir=home_dir+'/data/weather'
# !ls $data_dir
# Out:
# ALL.head.csv	  ghcnd-stations_buffered.txt  SAMPLE_TMAX.csv
# data-source.txt   ghcnd-stations.txt	       SAMPLE_TMAX.csv.old.gz
# ghcnd-readme.txt  ghcnd-version.txt

# %% [markdown]
# ### Get CDF of the statistics ###

# %%
# %%writefile Stations_TMin_TMax_Statistics.py
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class MRWeather(MRJob):
    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[0]=='station':
                yield (('header',1), 1)
            else:
                if elements[1] == 'TMIN':
                    num_defined = sum([e!='' for e in elements[3:]])
                    yield (('TMIN', num_defined), 1)
                elif elements[1] == 'TMAX':
                    num_defined = sum([e!='' for e in elements[3:]])
                    yield (('TMAX', num_defined), 1)
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error', 1),  1)

    def combiner(self, key, values):
        yield (key, sum(values))
    
    def reducer(self, key, values):
        self.increment_counter('MrJob Counters','reducer',1)
        yield (key, sum(values))
        
if __name__ == '__main__':
    MRWeather.run()
# Out:
# Writing Stations_TMin_TMax_Statistics.py

# %%
# !python Stations_TMin_TMax_Statistics.py -r emr --emr-job-flow-id  $job_flow_id $data_dir/ALL.head.csv > Station_TMin_TMax_Stat.txt
#!python Stations_TMin_TMax_Statistics.py -r emr --emr-job-flow-id  $job_flow_id  hdfs:/weather/weather.csv > DataCellNumForEachStation.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/Stations_TMin_TMax_Statistics.ubuntu.20140524.183220.037281
# Copying non-input files into s3://ruininghe/scratch/Stations_TMin_TMax_Statistics.ubuntu.20140524.183220.037281/files/
# Adding our job to existing job flow j-1RE8D7HBISOI0
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "Stations_TMin_TMax_Statistics.py", line 35, in <module>
#     MRWeather.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 213, in run_job
#     self.stdout.flush()
# ...

# %%
# %%writefile My_Stations_Statistics.py
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class MRWeather(MRJob):
    #@ECatch
    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[0]=='station':
                out = ('header',1)
            else:
                number_defined=sum([e!='' for e in elements[3:]])
                out = (elements[0], number_defined)
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            out=('error',1)

        finally:
            yield out    
    #@ECatch
    def combiner(self, key, values):
        yield (key, sum(values))
    
   # @ECatch
    def reducer(self, key, values):
        self.increment_counter('MrJob Counters','reducer',1)
        yield (key, sum(values))
        
if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting My_Stations_Statistics.py

# %%
# !python My_Stations_Statistics.py -r emr --emr-job-flow-id  $job_flow_id $data_dir/ALL.head.csv > DataCellNumForEachStation.txt
#!python My_Stations_Statistics.py -r emr --emr-job-flow-id  $job_flow_id  hdfs:/weather/weather.csv > DataCellNumForEachStation.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating new scratch bucket mrjob-ccc47f59e47777c1
# using s3://mrjob-ccc47f59e47777c1/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/My_Stations_Statistics.ubuntu.20140524.183503.555501
# creating S3 bucket 'mrjob-ccc47f59e47777c1' to use as scratch space
# Copying non-input files into s3://mrjob-ccc47f59e47777c1/tmp/My_Stations_Statistics.ubuntu.20140524.183503.555501/files/
# Adding our job to existing job flow j-1RE8D7HBISOI0
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "My_Stations_Statistics.py", line 36, in <module>
#     MRWeather.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
# ...

# %%
# !cat DataCellNumForEachStation.txt
# Out:
# "AJ000037668"	10014
# "AJ000037679"	9800
# "AJ000037734"	18856
# "AJ000037756"	16319
# "AJ000037844"	21929
# "AJ000037866"	11948
# "AJ000037888"	9412
# "AJ000037899"	16531
# "AJ000037907"	34353
# "AM000037627"	15836
# "AM000037704"	8673
# "AM000037773"	15322
# "AM000037872"	10730
# "AQC00914873"	17122
# "AR000000004"	6999
# "AR000000015"	6983
# "AR000087270"	42955
# "AR000087344"	46644
# "AR000087418"	44460
# "AR000087715"	44706
# "AR000087803"	42479
# "AR000870470"	34443
# "ASN00001000"	9095
# "ASN00001008"	6600
# "ASN00001011"	642
# "ASN00001019"	15102
# "ASN00001022"	1558
# "ASN00002001"	36672
# "ASN00002009"	30289
# "ASN00002012"	72773
# "ASN00002023"	26487
# "ASN00002034"	1553
# "ASN00002056"	32278
# "ASN00002067"	6542
# "ASN00002070"	335
# "ASN00003002"	61067
# "ASN00003013"	14658
# "ASN00003024"	17334
# "ASN00003035"	8465
# "ASN00003046"	5355
# "ASN00003057"	36914
# "ASN00003060"	2645
# "ASN00003068"	13862
# "ASN00003079"	3588
# "ASN00003082"	6542
# "ASN00003093"	16403
# ...

# %% [markdown]
# read data into a Pandas Dataframe

# %%
# !ls
# Out:
# coding.py			 README.txt
# counts				 reduce-year-temp.py
# DataCellNumForEachStation.txt	 stations.pkl.gz
# Description of Assignment.ipynb  Stations_Statistics.ipynb
# ECatch.py			 Stations_Statistics.py
# ECatch.pyc			 Statistics.py
# Eigen-by-Station.sh		 test.pkl
# map-year-temp.py		 test.txt
# mrjob and EMR.ipynb		 Untitled0.ipynb
# mr_weather.py			 weather_MRjob.ipynb
# mr_word_freq_count.py		 weather_MRjob-with-utils.ipynb
# My_Stations_Statistics.py

# %%
# !gunzip stations.pkl.gz
stations=pickle.load(open('stations.pkl', 'rb'))
# !gzip stations.pkl

#Days=pickle.load(open('Dates.pkl', 'rb'))

stations.head()
# Out:
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG  WMOID
# ACW00011604     NaN     NaN    NaN
# ACW00011647     NaN     NaN    NaN
# AE000041196     GSN     NaN  41196
# AF000040930     GSN     NaN  40930
# AG000060390     GSN     NaN  60390
#
# [5 rows x 8 columns]

# %%
header=['station','#measurement']
Data = pd.read_table('DataCellNumForEachStation.txt',header=None, names=header)
Data.head()
# Out:
#        station  #measurement
# 0  AJ000037668         10014
# 1  AJ000037679          9800
# 2  AJ000037734         18856
# 3  AJ000037756         16319
# 4  AJ000037844         21929
#
# [5 rows x 2 columns]

# %%
for i in range(len(Data)):
    Data.ix[i,"#measurement"] = math.log(Data.ix[i, "#measurement"]+1, 2)
Data.head()
# Out:
#        station  #measurement
# 0  AJ000037668      2.242523
# 1  AJ000037679      1.535422
# 2  AJ000037734      1.554160
# 3  AJ000037756      1.550194
# 4  AJ000037844      1.558208
#
# [5 rows x 2 columns]

# %%
Djoined=Data.join(stations,on='station')
Djoined.head()
# Out:
#        station  #measurement  latitude  longitude  elevation state       name  \
# 0  AJ000037668      2.242523    41.100     47.500        583   NaN  VARTASHEN
# 1  AJ000037679      1.535422    41.100     49.200        -26   NaN    SIASAN'
# 2  AJ000037734      1.554160    40.800     46.000        404   NaN    SHAMHOR
# 3  AJ000037756      1.550194    40.533     48.933        755   NaN     MARAZA
# 4  AJ000037844      1.558208    40.333     48.167          4   NaN   KURDAMIR
#
#   GSNFLAG HCNFLAG  WMOID
# 0     NaN     NaN  37668
# 1     NaN     NaN  37679
# 2     NaN     NaN  37734
# 3     NaN     NaN  37756
# 4     NaN     NaN  37844
#
# [5 rows x 10 columns]

# %%
lons=stations.ix[:,'longitude'].values
lats=stations.ix[:,'latitude'].values
station_names=stations.index.values
ll=len(lons)
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
select=(lons>lonmin) * (lons<lonmax)*(lats>latsmin)*(lats<latsmax)
print sum(select)
station_names=station_names[select]
lons=lons[select]
lats=lats[select]
print len(lons),len(lats),len(station_names)
# Out:
# 85273
# 85273 85273 85273

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats 
import scipy.stats as stats

plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,\
            llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
parallels = np.arange(-80,81,10.)
meridians = np.arange(10.,351.,20.)
m.drawparallels(parallels,labels=[False,True,True,False])
m.drawmeridians(meridians,labels=[True,False,False,True])
m.drawmapboundary(fill_color='aqua')

x,y = m(Djoined['longitude'].tolist(),Djoined['latitude'].tolist())
m.colorbar(m.scatter(x,y,c=Djoined['#measurement'].tolist(),marker='.',zorder=15, s=5,lw=0),location='bottom',pad="5%")
plt.title('color bar plot based on #measurement column data')
